# %% [markdown]
# # Introduction to Pandas

# %%
#importing pandas for data analysis
import pandas as pd

# %%
# creating data frame
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Head Function is use to display head results of the dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# info() function will give all the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# index will show you the total number of rows
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# values will show all the values
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
# to show the data types we will use dtypes
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # DataFrame and Series

# %%
d_1 = {"Age":[20,25,30], "Height":[167,170,173]}
data_1 = pd.DataFrame(d_1)
data_1
# Out:
#    Age  Height
# 0   20     167
# 1   25     170
# 2   30     173

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     3 non-null      int64
#  1   Height  3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
data = pd.read_csv("titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# to display only one column
data["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
age = data["Age"]
age[:7]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# Name: Age, dtype: float64

# %%
print(type(age))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = data.set_index("Name")
data.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
data["Age"][:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
# Name: Age, dtype: float64

# %%
age = data["Age"]
age["Heikkinen, Miss. Laina"]
# Out:
# 26.0

# %%
age[:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
# Name: Age, dtype: float64

# %%
age = age + 2
age[:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                24.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    40.0
# Heikkinen, Miss. Laina                                 28.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           37.0
# Allen, Mr. William Henry                               37.0
# Name: Age, dtype: float64

# %%
age = age * 1.3
age[:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                31.2
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    52.0
# Heikkinen, Miss. Laina                                 36.4
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           48.1
# Allen, Mr. William Henry                               48.1
# Name: Age, dtype: float64

# %%
# Calculate the mean of Age
age.mean()
# Out:
# 41.20885294117649

# %%
# calculate the min 
age.min()
# Out:
# 3.146

# %%
# Calculate max
age.max()
# Out:
# 106.60000000000001

# %%
# describe function is used to explore the dataset
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Indexing methods in Pandas
#
# **Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame. Indexing could mean selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns. Indexing can also be known as Subset Selection.**
#
# Link : https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html

# %%
data["Age"][:5]
# Out:
# Name
# Braund, Mr. Owen Harris                                22.0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    38.0
# Heikkinen, Miss. Laina                                 26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           35.0
# Allen, Mr. William Henry                               35.0
# Name: Age, dtype: float64

# %%
data[["Age","Fare"]][:5]
# Out:
#                                                      Age     Fare
# Name
# Braund, Mr. Owen Harris                             22.0   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0  71.2833
# Heikkinen, Miss. Laina                              26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0  53.1000
# Allen, Mr. William Henry                            35.0   8.0500

# %%
# iloc returns a Pandas Series when one row is selected, and a Pandas DataFrame when multiple rows are selected,
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html
data.iloc[0]
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
data.iloc[0:5]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
data.iloc[0:5,1:3]
# Out:
#                                                     Survived  Pclass
# Name
# Braund, Mr. Owen Harris                                    0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1
# Heikkinen, Miss. Laina                                     1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1
# Allen, Mr. William Henry                                   0       3

# %%
# The loc property is used to access a group of rows and columns by label(s) or a boolean array. 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
data.loc["Heikkinen, Miss. Laina"]
# Out:
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                        26.0
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
data.loc["Heikkinen, Miss. Laina","Age"]
# Out:
# 26.0

# %%
data.loc["Heikkinen, Miss. Laina":"Allen, Mr. William Henry"]
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Heikkinen, Miss. Laina                                  3         1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1       1
# Allen, Mr. William Henry                                5         0       3
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# Heikkinen, Miss. Laina                        female  26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# Allen, Mr. William Henry                        male  35.0      0      0
#
#                                                         Ticket    Fare Cabin  \
# Name
# Heikkinen, Miss. Laina                        STON/O2. 3101282   7.925   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803  53.100  C123
# Allen, Mr. William Henry                                373450   8.050   NaN
#
# ...

# %%
data.loc["Heikkinen, Miss. Laina":"Allen, Mr. William Henry",["Age","Fare"]]
# Out:
#                                                Age    Fare
# Name
# Heikkinen, Miss. Laina                        26.0   7.925
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.100
# Allen, Mr. William Henry                      35.0   8.050

# %%
data.loc["Heikkinen, Miss. Laina","Age"] = 400
data.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex    Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male   22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female   38.0
# Heikkinen, Miss. Laina                                   3  female  400.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female   35.0
# Allen, Mr. William Henry                                 3    male   35.0
#
# ...

# %%
data [data["Age"]>30]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# McCarthy, Mr. Timothy J                                       7         0
# ...                                                         ...       ...
# Vander Cruyssen, Mr. Victor                                 874         0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Markun, Mr. Johann                                          882         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
data [data["Sex"]=="female"]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# ...                                                         ...       ...
# Shelley, Mrs. William (Imanita Parrish Hall)                881         1
# Dahlberg, Miss. Gerda Ulrika                                883         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
#
# ...

# %%
data.loc[data["Sex"]=="male","Age"].mean()
# Out:
# 30.72664459161148

# %%
(data["Age"]>65).sum()
# Out:
# 9

# %% [markdown]
# # Groupby in Pandas
#
# **Pandas' GroupBy is a powerful and versatile function in Python. It allows you to split your data into separate groups to perform computations for better analysis.30**
#
# Link : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %%
data_1 = pd.DataFrame({"K":["A","B","C","D","A","B","C","D"],
                      "data":[1,3,4,3,2,5,3,2]})
data_1
# Out:
#    K  data
# 0  A     1
# 1  B     3
# 2  C     4
# 3  D     3
# 4  A     2
# 5  B     5
# 6  C     3
# 7  D     2

# %%
data_1.groupby("K").sum()
# Out:
#    data
# K
# A     3
# B     8
# C     7
# D     5

# %%
import numpy as np
data_1.groupby("K").aggregate(np.mean)
# Out:
#    data
# K
# A   1.5
# B   4.0
# C   3.5
# D   2.5

# %%
data.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex    Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male   22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female   38.0
# Heikkinen, Miss. Laina                                   3  female  400.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female   35.0
# Allen, Mr. William Henry                                 3    male   35.0
#
# ...

# %%
data.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    29.348659
# male      30.726645
# Name: Age, dtype: float64

# %%
data.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# # Mathematical Operations in Pandas

# %%
data_1 = pd.DataFrame([[1,2,3],[4,5,6]],index=["a","b"],columns=["A1","B1","C1"])
data_1
# Out:
#    A1  B1  C1
# a   1   2   3
# b   4   5   6

# %%
data_1.sum()
# Out:
# A1    5
# B1    7
# C1    9
# dtype: int64

# %%
data_1.sum(axis=1)
# Out:
# a     6
# b    15
# dtype: int64

# %%
data_1.mean()
# Out:
# A1    2.5
# B1    3.5
# C1    4.5
# dtype: float64

# %%
data_1.max()
# Out:
# A1    4
# B1    5
# C1    6
# dtype: int64

# %%
data.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex    Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male   22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female   38.0
# Heikkinen, Miss. Laina                                   3  female  400.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female   35.0
# Allen, Mr. William Henry                                 3    male   35.0
#
# ...

# %%
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data["Pclass"].value_counts(ascending=True)
# Out:
# 2    184
# 1    216
# 3    491
# Name: Pclass, dtype: int64
